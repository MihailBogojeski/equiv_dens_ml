# %%
import os
import sys
import numpy as np
from pyscf import gto
from pyscf import scf,dft
from ase.io import read
from scipy import special
import argparse
from pyscf import grad
# Out:
# /home/mihail/anaconda3/envs/equiv_dens/lib/python3.7/site-packages/pyscf/lib/misc.py:47: H5pyDeprecationWarning: Using default_file_mode other than 'r' is deprecated. Pass the mode to h5py.File() instead.
#   h5py.get_config().default_file_mode = 'a'

# %%
water_mo = np.load('datasets/h2o_dynamic_pyscf_dft_f_en.npy', allow_pickle=True)
water_data = np.load('datasets/h2o_dynamic_centered.npy', allow_pickle=True).item()
